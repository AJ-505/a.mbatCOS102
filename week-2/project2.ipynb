# %%
import numpy as np

def calculate_quadratic_equation():
  print("Alright. Let's begin calculating the quadratic equation.")
  a = int(input("What is the coefficient of x^2?"))
  b = int(input("What is the coefficient of x?"))
  c = int(input("What is the constant C in this equation?"))
  ans1 = (-b + (b**2 - 4*a*c) ** 0.5) / (2*a)
  ans2 = (-b - (b**2 - 4*a*c) ** 0.5) / (2*a)
  print(f"The solutions to this equation are {ans1} and {ans2}")

def calculate_cubic_equation():
  print("Alright. Let's begin calculating the cubic equation.")
  a = int(input("What is the coefficient of x^3?"))
  b = int(input("What is the coefficient of x^2?"))
  c = int(input("What is the coefficient of x?"))
  d = int(input("What is the constant C in this equation?"))
  coefficients = [a, b, c, d]
  solutions = np.roots(coefficients) #This is necessary as there is no straightforward formula for a cubic equation, due to the nature of the equation
  print("The solutions to this cubic equation are: ", end="")
  for i in solutions:
    if i == solutions[-1]:
      print(f"and {i}", end=".\n")
    else:
      print(i, end=", ")

def calculate_quartic_equation():
  print("Alright. Let's begin calculating the quartic equation.")
  a = int(input("What is the coefficient of x^4?"))
  b = int(input("What is the coefficient of x^3?"))
  c = int(input("What is the coefficient of x^2?"))
  d = int(input("What is the coefficient of x?"))
  e = int(input("What is the constant e in this equation?"))
  i = 0 + 1j
  ans1 = (-b + (b**2 - 4*a*c - (2*a)*d*d) ** 0.5) / (2*a)
  ans2 = (-b - (b**2 - 4*a*c - (2*a)*d*d) ** 0.5) / (2*a)
  ans3 = (-b + (i * (4*a*d*d - b*b + (2*a)*c) ** 0.5)) / (2*a)
  ans4 = (-b - (i * (4*a*d*d - b*b + (2*a)*c) ** 0.5)) / (2*a)
  print(f"The solutions to this equation are {ans1}, {ans2}, {ans3} and {ans4}")

  
print("Hello,\n Welcome to my equation root finder application!")
print("""
      What calculation would you like to perform?
      1. Quadratic equation (press 1)
      2. Cubic equation (press 2)            
      3. Quartic equation (press 3)
      Note: Only integer values are valid for these calculations to be computed successfully.
      """)
response = None
try:
  response = int(input().strip())
  print(response)
  match response:
    case 1:
      calculate_quadratic_equation()
    case 2:
      calculate_cubic_equation()
    case 3:
      calculate_quartic_equation()
    case _:
      print("Your input is invalid. Please enter a valid integer input.")
except Exception as e:
  print("Your input is invalid. Please enter a valid integer input.")
  
print("Thank you for using my program!")
# Out:
# Hello,
#  Welcome to my equation root finder application!
#
#       What calculation would you like to perform?
#       1. Quadratic equation (press 1)
#       2. Cubic equation (press 2)
#       3. Quartic equation (press 3)
#       Note: Only integer values are valid for these calculations to be computed successfully.
#
# 2
# Alright. Let's begin calculating the cubic equation.
# The solutions to this cubic equation are: (-1.6506291914393885+0j), (-0.17468540428030543+1.5468688872313967j), and (-0.17468540428030543-1.5468688872313967j).
# Thank you for using my program!
